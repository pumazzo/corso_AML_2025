# %% [markdown]
# <a href="https://colab.research.google.com/github/pumazzo/corso_AML_2025/blob/main/Lesson__0_pytorch_soda_can_class_version3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Optimization of Surface-to-Volume Ratio in a Cylinder
# [SLIDES](https://docs.google.com/presentation/d/1k5Ad5V_8sgvdTDyRzwxOhGObPCrzT_oXOlaZ8PjMGes/edit?usp=sharing)
#
# ## Problem Statement
#
# Given a cylindrical can of fixed volume $(V_0)$, we want to determine the radius $(r)$ that minimizes the surface-to-volume ratio. The surface area is related to material cost, so minimizing this ratio is important for cost efficiency.
#
# ## Define the Surface Area and Volume
#
# - **Volume**:
#   $$ V = \pi r^2 h $$
# - **Surface Area** (sum of lateral and two circular areas):
#   $$ S = 2\pi r h + 2\pi r^2 $$
#
# We aim to minimize the ratio $(S/V)$:
#
# $$ \frac{S}{V} = \frac{2\pi r h + 2\pi r^2}{\pi r^2 h} $$
#
#
#
# $$= \frac{2(h+r)}{rh}$$
#
# ## T fixed volume $(V=33\ cl)$
#
#
# $$
# \frac{S}{V} = \frac{2}{r} + \frac{2\pi r^2}{V_0}
# $$
#
#
#
# ##Find the Critical Points
#
# To minimize $(S/V)$, we take the derivative with respect to $(r)$:
#
# $$
# \frac{d}{dr} \left( \frac{2}{r} + \frac{2\pi r^2}{V_0} \right) = -\frac{2}{r^2} + \frac{4\pi r}{V_0}
# $$
#
# Setting the derivative to zero:
#
# $$
# -\frac{2}{r^2} + \frac{4\pi r}{V_0} = 0
# $$
#
#
#
# $$
# r = \left(\frac{V_0}{2\pi}\right)^{\frac{1}{3}}
# $$

# %%
# soda can problem
V0 = 330
SoverV0 = lambda r: (2/r + (2*np.pi * r **2) / V0)
R_opt = (V0/(2*np.pi))**(1/3)

# %%
r = np.linspace(0.2,20,300)
y = SoverV0(r)

# %%
plt.plot(r,y)
plt.axvline(R_opt,linestyle="--",label=f"optimal radius {np.round(R_opt,2)}")
plt.legend()
plt.xlabel("Radius (cm)" , fontsize =17)
plt.ylabel("Surface Volume ratio (cm^-1)", fontsize =17)
# Out:
# Text(0, 0.5, 'Surface Volume ratio (cm^-1)')

# %% [markdown]
# # Summary: How Gradient Descent Works
#
# Gradient Descent is an optimization algorithm used to minimize a function by iteratively adjusting its parameters in the direction of the steepest descent, as defined by the negative gradient.
#
# ## Key Steps:
# 1. **Initialize Parameters**: Start with random values for the parameters \( \theta \).
# 2. **Compute the Gradient**: Calculate the derivative (gradient) of the function with respect to the parameters.
# 3. **Update the Parameters**: Move in the direction of the negative gradient using the update rule:
#
#    $$
#    \theta \leftarrow \theta - \eta \nabla f(\theta)
#    $$
#
#    where  $\eta$ (learning rate) controls the step size.
# 4. **Repeat**: Continue updating until convergence (when the gradient is close to zero or changes are minimal).
#
# ## What's about Machine Learning and Gradient Descent?
#
# It is the same idea, but instead of minimizing any arbitrary function (like \( S/V \) in the soda can problem), we want to minimize the **expected value of the loss (or error) function** over the training data.
#
# ### Loss Function:
#
# For a dataset with \( N \) samples, where each sample has a true target $ y_i$ and a predicted value $\tilde{y}_i(w) $, the total loss is computed as:
#
# $$
# L(w) = \frac{1}{N} \sum_{i=1}^{N} l_w(y_i, \tilde{y}_i)
# $$
#
# where:
# - $ L(w)$ is the total loss function we aim to minimize.
# - $ l_w(y_i, \tilde{y}_i) $ is the loss for each individual training sample, measuring the difference between the predicted and true values.
# - $ w $ represents the model parameters (e.g., weights in a neural network).
#
# ### Optimization in Machine Learning:
#
# We update the model parameters using **Gradient Descent**:
#
# $$
# w \leftarrow w - \eta \nabla L(w)
# $$
#
# ## types of gradient descent (the element on which the sum is computed with)
#
#
# - **Batch Gradient Descent**: Uses the entire dataset to compute the gradient.
# - **Stochastic Gradient Descent (SGD)**: Updates parameters using a single random data point per iteration.
# - **Mini-Batch Gradient Descent**: Uses a small batch of data to balance efficiency and stability.

# %%
class SoverVoptimizer():
    def __init__(self, V0, learning_rate=0.1, epochs=400):
        self.V0 = V0  # Fixed volume
        self.learning_rate = learning_rate  # Step size

        self.epochs = epochs  # Maximum number of iterations
        self.r_history = []  # Store the radius at each step
        self.f_history = []

    def forward(self, r):
        """Function to optimize: S/V = 2/r + (2 * pi * r^2) / V0"""
        return 2 / r + (2 * np.pi * r ** 2) / self.V0

    def derivative(self, r):# like old timers, we need to compute the derivative by hand
        """Derivative of the objective function."""
        return -2 / r**2 + (4 * np.pi * r) / self.V0

    def do_a_step(self, r):
        """Perform a single step of gradient descent."""
        gradient = self.derivative(r)
        return r - self.learning_rate * gradient  # Update radius

    def optimize(self, r_init):#In machine learnig we call this part "train"
        """Run the gradient descent optimization."""
        r = r_init
        self.r_history.append(r)

        f = self.forward(r)
        self.f_history.append(f)


        for i in range(self.epochs):
            new_r = self.do_a_step(r)
            self.r_history.append(new_r)
            f = self.forward(new_r)
            self.f_history.append(f)
            r = new_r

        return r  # Return the optimized radius


V0 = 330  # Fixed volume
SodaCan = SoverVoptimizer(V0, learning_rate=0.2)
optimal_r = SodaCan.optimize(r_init=20)  # Start from an initial guess of r

print(f"Optimal radius: {optimal_r}")
# Out:
# Optimal radius: 3.763808225486353

# %%
plt.plot(SodaCan.r_history,SodaCan.f_history,"+",label= "optimization steps")
plt.plot(r,y,label= "theoretical curve")
plt.axvline(R_opt,linestyle="--",label=f"optimal radius {np.round(R_opt,2)}")
plt.xlabel("Radius (cm)" , fontsize =17)
plt.ylabel("Surface Volume ratio (cm^-1)", fontsize =17)
plt.axvline(20,linestyle="--",label="init",color="k")
plt.legend()

# %%
import torch

# %%
import torch.nn as nn

# %%
class SodaCan(nn.Module):
  def __init__(self,V0, lr=0.01):
    super(SodaCan, self).__init__()

    self.V0 = V0#


    self.pi = torch.acos(torch.zeros(1))*2 # no pi in torch

    self.R = nn.Parameter(torch.Tensor([20])) # initial R set to 20
    self.R.requires_grad = True



  def forward(self):

    return 2/self.R + (2*self.pi*self.R**2)/self.V0

# %%
sov = SodaCan(330,lr=0.2)
sov.forward()
# Out:
# tensor([7.7160], grad_fn=<AddBackward0>)

# %%
sov()# execute the forward
# Out:
# tensor([7.7160], grad_fn=<AddBackward0>)

# %%
for p in sov.parameters():
  print(p)
# Out:
# Parameter containing:
# tensor([20.], requires_grad=True)

# %%
sov.R
sov()
# Out:
# tensor([7.7160], grad_fn=<AddBackward0>)

# %%
import torch.optim as optim
optimizer = optim.SGD(sov.parameters(), lr=0.2)


R=[]
value=[]
for epoch in range(500):
  optimizer.zero_grad()
  f_computed_in_R = sov()
  sov().backward()
  optimizer.step()
  newR = sov.R.item()
  R.append(newR)
  value.append(f_computed_in_R.item())
  print("new R : ", newR, "f(R) : ", f_computed_in_R)
# Out:
# new R :  19.84868049621582 f(R) :  tensor([7.7160], grad_fn=<AddBackward0>)
# new R :  19.698528289794922 f(R) :  tensor([7.6019], grad_fn=<AddBackward0>)
# new R :  19.549535751342773 f(R) :  tensor([7.4896], grad_fn=<AddBackward0>)
# new R :  19.40169334411621 f(R) :  tensor([7.3791], grad_fn=<AddBackward0>)
# new R :  19.254993438720703 f(R) :  tensor([7.2702], grad_fn=<AddBackward0>)
# new R :  19.109426498413086 f(R) :  tensor([7.1630], grad_fn=<AddBackward0>)
# new R :  18.964984893798828 f(R) :  tensor([7.0575], grad_fn=<AddBackward0>)
# new R :  18.821659088134766 f(R) :  tensor([6.9536], grad_fn=<AddBackward0>)
# new R :  18.679443359375 f(R) :  tensor([6.8513], grad_fn=<AddBackward0>)
# new R :  18.538328170776367 f(R) :  tensor([6.7505], grad_fn=<AddBackward0>)
# new R :  18.398303985595703 f(R) :  tensor([6.6513], grad_fn=<AddBackward0>)
# new R :  18.25936508178711 f(R) :  tensor([6.5537], grad_fn=<AddBackward0>)
# new R :  18.121501922607422 f(R) :  tensor([6.4575], grad_fn=<AddBackward0>)
# new R :  17.98470687866211 f(R) :  tensor([6.3629], grad_fn=<AddBackward0>)
# new R :  17.84897232055664 f(R) :  tensor([6.2697], grad_fn=<AddBackward0>)
# new R :  17.714290618896484 f(R) :  tensor([6.1779], grad_fn=<AddBackward0>)
# new R :  17.58065414428711 f(R) :  tensor([6.0876], grad_fn=<AddBackward0>)
# new R :  17.448055267333984 f(R) :  tensor([5.9986], grad_fn=<AddBackward0>)
# new R :  17.316484451293945 f(R) :  tensor([5.9110], grad_fn=<AddBackward0>)
# new R :  17.185935974121094 f(R) :  tensor([5.8248], grad_fn=<AddBackward0>)
# new R :  17.0564022064209 f(R) :  tensor([5.7399], grad_fn=<AddBackward0>)
# new R :  16.927875518798828 f(R) :  tensor([5.6564], grad_fn=<AddBackward0>)
# new R :  16.80034828186035 f(R) :  tensor([5.5741], grad_fn=<AddBackward0>)
# new R :  16.67381477355957 f(R) :  tensor([5.4931], grad_fn=<AddBackward0>)
# new R :  16.54826545715332 f(R) :  tensor([5.4134], grad_fn=<AddBackward0>)
# new R :  16.423694610595703 f(R) :  tensor([5.3349], grad_fn=<AddBackward0>)
# new R :  16.300094604492188 f(R) :  tensor([5.2576], grad_fn=<AddBackward0>)
# new R :  16.177459716796875 f(R) :  tensor([5.1815], grad_fn=<AddBackward0>)
# new R :  16.0557804107666 f(R) :  tensor([5.1066], grad_fn=<AddBackward0>)
# new R :  15.935051918029785 f(R) :  tensor([5.0328], grad_fn=<AddBackward0>)
# new R :  15.815265655517578 f(R) :  tensor([4.9602], grad_fn=<AddBackward0>)
# new R :  15.696415901184082 f(R) :  tensor([4.8888], grad_fn=<AddBackward0>)
# new R :  15.578495979309082 f(R) :  tensor([4.8184], grad_fn=<AddBackward0>)
# new R :  15.461498260498047 f(R) :  tensor([4.7492], grad_fn=<AddBackward0>)
# new R :  15.345417022705078 f(R) :  tensor([4.6810], grad_fn=<AddBackward0>)
# new R :  15.230245590209961 f(R) :  tensor([4.6139], grad_fn=<AddBackward0>)
# new R :  15.115976333618164 f(R) :  tensor([4.5478], grad_fn=<AddBackward0>)
# new R :  15.002603530883789 f(R) :  tensor([4.4828], grad_fn=<AddBackward0>)
# new R :  14.890121459960938 f(R) :  tensor([4.4188], grad_fn=<AddBackward0>)
# new R :  14.778522491455078 f(R) :  tensor([4.3558], grad_fn=<AddBackward0>)
# new R :  14.667800903320312 f(R) :  tensor([4.2937], grad_fn=<AddBackward0>)
# new R :  14.557950019836426 f(R) :  tensor([4.2327], grad_fn=<AddBackward0>)
# new R :  14.44896411895752 f(R) :  tensor([4.1726], grad_fn=<AddBackward0>)
# new R :  14.340837478637695 f(R) :  tensor([4.1134], grad_fn=<AddBackward0>)
# new R :  14.233562469482422 f(R) :  tensor([4.0552], grad_fn=<AddBackward0>)
# new R :  14.127134323120117 f(R) :  tensor([3.9979], grad_fn=<AddBackward0>)
# new R :  14.021546363830566 f(R) :  tensor([3.9415], grad_fn=<AddBackward0>)
# new R :  13.916792869567871 f(R) :  tensor([3.8860], grad_fn=<AddBackward0>)
# new R :  13.812868118286133 f(R) :  tensor([3.8313], grad_fn=<AddBackward0>)
# new R :  13.709766387939453 f(R) :  tensor([3.7775], grad_fn=<AddBackward0>)
# new R :  13.607481002807617 f(R) :  tensor([3.7246], grad_fn=<AddBackward0>)
# new R :  13.506007194519043 f(R) :  tensor([3.6725], grad_fn=<AddBackward0>)
# new R :  13.405338287353516 f(R) :  tensor([3.6212], grad_fn=<AddBackward0>)
# new R :  13.305469512939453 f(R) :  tensor([3.5707], grad_fn=<AddBackward0>)
# new R :  13.206395149230957 f(R) :  tensor([3.5211], grad_fn=<AddBackward0>)
# new R :  13.108108520507812 f(R) :  tensor([3.4722], grad_fn=<AddBackward0>)
# new R :  13.010605812072754 f(R) :  tensor([3.4241], grad_fn=<AddBackward0>)
# new R :  12.913880348205566 f(R) :  tensor([3.3767], grad_fn=<AddBackward0>)
# new R :  12.817927360534668 f(R) :  tensor([3.3301], grad_fn=<AddBackward0>)
# new R :  12.72274112701416 f(R) :  tensor([3.2843], grad_fn=<AddBackward0>)
# new R :  12.628315925598145 f(R) :  tensor([3.2392], grad_fn=<AddBackward0>)
# new R :  12.534646987915039 f(R) :  tensor([3.1948], grad_fn=<AddBackward0>)
# new R :  12.441729545593262 f(R) :  tensor([3.1511], grad_fn=<AddBackward0>)
# new R :  12.349557876586914 f(R) :  tensor([3.1081], grad_fn=<AddBackward0>)
# new R :  12.258126258850098 f(R) :  tensor([3.0658], grad_fn=<AddBackward0>)
# new R :  12.167430877685547 f(R) :  tensor([3.0241], grad_fn=<AddBackward0>)
# new R :  12.077466011047363 f(R) :  tensor([2.9832], grad_fn=<AddBackward0>)
# new R :  11.988226890563965 f(R) :  tensor([2.9429], grad_fn=<AddBackward0>)
# new R :  11.899707794189453 f(R) :  tensor([2.9032], grad_fn=<AddBackward0>)
# new R :  11.811904907226562 f(R) :  tensor([2.8642], grad_fn=<AddBackward0>)
# new R :  11.724812507629395 f(R) :  tensor([2.8258], grad_fn=<AddBackward0>)
# new R :  11.638425827026367 f(R) :  tensor([2.7880], grad_fn=<AddBackward0>)
# new R :  11.552741050720215 f(R) :  tensor([2.7509], grad_fn=<AddBackward0>)
# new R :  11.467752456665039 f(R) :  tensor([2.7143], grad_fn=<AddBackward0>)
# new R :  11.383456230163574 f(R) :  tensor([2.6783], grad_fn=<AddBackward0>)
# new R :  11.299846649169922 f(R) :  tensor([2.6429], grad_fn=<AddBackward0>)
# new R :  11.216919898986816 f(R) :  tensor([2.6081], grad_fn=<AddBackward0>)
# new R :  11.134671211242676 f(R) :  tensor([2.5739], grad_fn=<AddBackward0>)
# new R :  11.053095817565918 f(R) :  tensor([2.5402], grad_fn=<AddBackward0>)
# new R :  10.972189903259277 f(R) :  tensor([2.5071], grad_fn=<AddBackward0>)
# new R :  10.891948699951172 f(R) :  tensor([2.4745], grad_fn=<AddBackward0>)
# new R :  10.81236743927002 f(R) :  tensor([2.4424], grad_fn=<AddBackward0>)
# new R :  10.733442306518555 f(R) :  tensor([2.4109], grad_fn=<AddBackward0>)
# new R :  10.655168533325195 f(R) :  tensor([2.3799], grad_fn=<AddBackward0>)
# new R :  10.577542304992676 f(R) :  tensor([2.3494], grad_fn=<AddBackward0>)
# new R :  10.500558853149414 f(R) :  tensor([2.3194], grad_fn=<AddBackward0>)
# new R :  10.424214363098145 f(R) :  tensor([2.2898], grad_fn=<AddBackward0>)
# new R :  10.348505020141602 f(R) :  tensor([2.2608], grad_fn=<AddBackward0>)
# new R :  10.273426055908203 f(R) :  tensor([2.2323], grad_fn=<AddBackward0>)
# new R :  10.198973655700684 f(R) :  tensor([2.2042], grad_fn=<AddBackward0>)
# new R :  10.125144004821777 f(R) :  tensor([2.1766], grad_fn=<AddBackward0>)
# new R :  10.051933288574219 f(R) :  tensor([2.1495], grad_fn=<AddBackward0>)
# new R :  9.979336738586426 f(R) :  tensor([2.1228], grad_fn=<AddBackward0>)
# new R :  9.907350540161133 f(R) :  tensor([2.0965], grad_fn=<AddBackward0>)
# new R :  9.83597183227539 f(R) :  tensor([2.0707], grad_fn=<AddBackward0>)
# new R :  9.765195846557617 f(R) :  tensor([2.0454], grad_fn=<AddBackward0>)
# new R :  9.695018768310547 f(R) :  tensor([2.0204], grad_fn=<AddBackward0>)
# new R :  9.62543773651123 f(R) :  tensor([1.9959], grad_fn=<AddBackward0>)
# new R :  9.556447982788086 f(R) :  tensor([1.9718], grad_fn=<AddBackward0>)
# new R :  9.488046646118164 f(R) :  tensor([1.9481], grad_fn=<AddBackward0>)
# new R :  9.420228958129883 f(R) :  tensor([1.9248], grad_fn=<AddBackward0>)
# new R :  9.352992057800293 f(R) :  tensor([1.9019], grad_fn=<AddBackward0>)
# new R :  9.286332130432129 f(R) :  tensor([1.8794], grad_fn=<AddBackward0>)
# new R :  9.220246315002441 f(R) :  tensor([1.8573], grad_fn=<AddBackward0>)
# new R :  9.154729843139648 f(R) :  tensor([1.8356], grad_fn=<AddBackward0>)
# new R :  9.089780807495117 f(R) :  tensor([1.8142], grad_fn=<AddBackward0>)
# new R :  9.025394439697266 f(R) :  tensor([1.7932], grad_fn=<AddBackward0>)
# new R :  8.961567878723145 f(R) :  tensor([1.7725], grad_fn=<AddBackward0>)
# new R :  8.898297309875488 f(R) :  tensor([1.7523], grad_fn=<AddBackward0>)
# new R :  8.835579872131348 f(R) :  tensor([1.7323], grad_fn=<AddBackward0>)
# new R :  8.773411750793457 f(R) :  tensor([1.7128], grad_fn=<AddBackward0>)
# new R :  8.711790084838867 f(R) :  tensor([1.6935], grad_fn=<AddBackward0>)
# new R :  8.650712013244629 f(R) :  tensor([1.6746], grad_fn=<AddBackward0>)
# new R :  8.590173721313477 f(R) :  tensor([1.6560], grad_fn=<AddBackward0>)
# new R :  8.530171394348145 f(R) :  tensor([1.6378], grad_fn=<AddBackward0>)
# new R :  8.470703125 f(R) :  tensor([1.6199], grad_fn=<AddBackward0>)
# new R :  8.411765098571777 f(R) :  tensor([1.6023], grad_fn=<AddBackward0>)
# new R :  8.353354454040527 f(R) :  tensor([1.5850], grad_fn=<AddBackward0>)
# new R :  8.2954683303833 f(R) :  tensor([1.5680], grad_fn=<AddBackward0>)
# new R :  8.238102912902832 f(R) :  tensor([1.5513], grad_fn=<AddBackward0>)
# new R :  8.181255340576172 f(R) :  tensor([1.5349], grad_fn=<AddBackward0>)
# new R :  8.124922752380371 f(R) :  tensor([1.5189], grad_fn=<AddBackward0>)
# new R :  8.069103240966797 f(R) :  tensor([1.5031], grad_fn=<AddBackward0>)
# new R :  8.013792037963867 f(R) :  tensor([1.4876], grad_fn=<AddBackward0>)
# new R :  7.958987712860107 f(R) :  tensor([1.4723], grad_fn=<AddBackward0>)
# new R :  7.90468692779541 f(R) :  tensor([1.4574], grad_fn=<AddBackward0>)
# new R :  7.850886821746826 f(R) :  tensor([1.4427], grad_fn=<AddBackward0>)
# new R :  7.797584056854248 f(R) :  tensor([1.4283], grad_fn=<AddBackward0>)
# new R :  7.744776725769043 f(R) :  tensor([1.4142], grad_fn=<AddBackward0>)
# new R :  7.6924614906311035 f(R) :  tensor([1.4003], grad_fn=<AddBackward0>)
# new R :  7.6406354904174805 f(R) :  tensor([1.3867], grad_fn=<AddBackward0>)
# new R :  7.589296340942383 f(R) :  tensor([1.3733], grad_fn=<AddBackward0>)
# new R :  7.538441181182861 f(R) :  tensor([1.3602], grad_fn=<AddBackward0>)
# new R :  7.488067150115967 f(R) :  tensor([1.3473], grad_fn=<AddBackward0>)
# new R :  7.438171863555908 f(R) :  tensor([1.3347], grad_fn=<AddBackward0>)
# new R :  7.3887529373168945 f(R) :  tensor([1.3223], grad_fn=<AddBackward0>)
# new R :  7.339807033538818 f(R) :  tensor([1.3101], grad_fn=<AddBackward0>)
# new R :  7.291332244873047 f(R) :  tensor([1.2982], grad_fn=<AddBackward0>)
# new R :  7.243325710296631 f(R) :  tensor([1.2865], grad_fn=<AddBackward0>)
# new R :  7.195784568786621 f(R) :  tensor([1.2751], grad_fn=<AddBackward0>)
# new R :  7.148706912994385 f(R) :  tensor([1.2638], grad_fn=<AddBackward0>)
# new R :  7.102089881896973 f(R) :  tensor([1.2528], grad_fn=<AddBackward0>)
# new R :  7.0559306144714355 f(R) :  tensor([1.2420], grad_fn=<AddBackward0>)
# new R :  7.010227203369141 f(R) :  tensor([1.2314], grad_fn=<AddBackward0>)
# new R :  6.964976787567139 f(R) :  tensor([1.2210], grad_fn=<AddBackward0>)
# new R :  6.920176982879639 f(R) :  tensor([1.2108], grad_fn=<AddBackward0>)
# new R :  6.875825881958008 f(R) :  tensor([1.2008], grad_fn=<AddBackward0>)
# new R :  6.831920623779297 f(R) :  tensor([1.1910], grad_fn=<AddBackward0>)
# new R :  6.788458824157715 f(R) :  tensor([1.1814], grad_fn=<AddBackward0>)
# new R :  6.745438098907471 f(R) :  tensor([1.1720], grad_fn=<AddBackward0>)
# new R :  6.702856063842773 f(R) :  tensor([1.1628], grad_fn=<AddBackward0>)
# new R :  6.660710334777832 f(R) :  tensor([1.1538], grad_fn=<AddBackward0>)
# new R :  6.6189985275268555 f(R) :  tensor([1.1450], grad_fn=<AddBackward0>)
# new R :  6.577718257904053 f(R) :  tensor([1.1363], grad_fn=<AddBackward0>)
# new R :  6.536867618560791 f(R) :  tensor([1.1278], grad_fn=<AddBackward0>)
# new R :  6.496443748474121 f(R) :  tensor([1.1195], grad_fn=<AddBackward0>)
# new R :  6.45644474029541 f(R) :  tensor([1.1114], grad_fn=<AddBackward0>)
# new R :  6.416868209838867 f(R) :  tensor([1.1035], grad_fn=<AddBackward0>)
# new R :  6.377711772918701 f(R) :  tensor([1.0957], grad_fn=<AddBackward0>)
# new R :  6.338973045349121 f(R) :  tensor([1.0880], grad_fn=<AddBackward0>)
# new R :  6.300650119781494 f(R) :  tensor([1.0806], grad_fn=<AddBackward0>)
# new R :  6.262740612030029 f(R) :  tensor([1.0733], grad_fn=<AddBackward0>)
# new R :  6.2252421379089355 f(R) :  tensor([1.0661], grad_fn=<AddBackward0>)
# new R :  6.188152313232422 f(R) :  tensor([1.0591], grad_fn=<AddBackward0>)
# new R :  6.1514692306518555 f(R) :  tensor([1.0523], grad_fn=<AddBackward0>)
# new R :  6.115190505981445 f(R) :  tensor([1.0456], grad_fn=<AddBackward0>)
# new R :  6.0793137550354 f(R) :  tensor([1.0391], grad_fn=<AddBackward0>)
# new R :  6.043837070465088 f(R) :  tensor([1.0327], grad_fn=<AddBackward0>)
# new R :  6.008757591247559 f(R) :  tensor([1.0264], grad_fn=<AddBackward0>)
# new R :  5.974073886871338 f(R) :  tensor([1.0203], grad_fn=<AddBackward0>)
# new R :  5.939783096313477 f(R) :  tensor([1.0143], grad_fn=<AddBackward0>)
# new R :  5.905883312225342 f(R) :  tensor([1.0085], grad_fn=<AddBackward0>)
# new R :  5.872372150421143 f(R) :  tensor([1.0027], grad_fn=<AddBackward0>)
# new R :  5.839247703552246 f(R) :  tensor([0.9972], grad_fn=<AddBackward0>)
# new R :  5.806507587432861 f(R) :  tensor([0.9917], grad_fn=<AddBackward0>)
# new R :  5.774149417877197 f(R) :  tensor([0.9864], grad_fn=<AddBackward0>)
# new R :  5.742170810699463 f(R) :  tensor([0.9812], grad_fn=<AddBackward0>)
# new R :  5.710569858551025 f(R) :  tensor([0.9761], grad_fn=<AddBackward0>)
# new R :  5.679344177246094 f(R) :  tensor([0.9711], grad_fn=<AddBackward0>)
# new R :  5.648491382598877 f(R) :  tensor([0.9663], grad_fn=<AddBackward0>)
# new R :  5.618009567260742 f(R) :  tensor([0.9616], grad_fn=<AddBackward0>)
# new R :  5.587896347045898 f(R) :  tensor([0.9569], grad_fn=<AddBackward0>)
# new R :  5.558149337768555 f(R) :  tensor([0.9524], grad_fn=<AddBackward0>)
# new R :  5.528766632080078 f(R) :  tensor([0.9480], grad_fn=<AddBackward0>)
# new R :  5.4997453689575195 f(R) :  tensor([0.9437], grad_fn=<AddBackward0>)
# new R :  5.471083641052246 f(R) :  tensor([0.9396], grad_fn=<AddBackward0>)
# new R :  5.442779064178467 f(R) :  tensor([0.9355], grad_fn=<AddBackward0>)
# new R :  5.414829730987549 f(R) :  tensor([0.9315], grad_fn=<AddBackward0>)
# new R :  5.387232780456543 f(R) :  tensor([0.9276], grad_fn=<AddBackward0>)
# new R :  5.359986305236816 f(R) :  tensor([0.9238], grad_fn=<AddBackward0>)
# new R :  5.333087921142578 f(R) :  tensor([0.9201], grad_fn=<AddBackward0>)
# new R :  5.306535243988037 f(R) :  tensor([0.9165], grad_fn=<AddBackward0>)
# new R :  5.280325889587402 f(R) :  tensor([0.9130], grad_fn=<AddBackward0>)
# new R :  5.254457473754883 f(R) :  tensor([0.9096], grad_fn=<AddBackward0>)
# new R :  5.2289276123046875 f(R) :  tensor([0.9063], grad_fn=<AddBackward0>)
# new R :  5.203733921051025 f(R) :  tensor([0.9031], grad_fn=<AddBackward0>)
# new R :  5.1788740158081055 f(R) :  tensor([0.8999], grad_fn=<AddBackward0>)
# new R :  5.154345512390137 f(R) :  tensor([0.8968], grad_fn=<AddBackward0>)
# new R :  5.130146026611328 f(R) :  tensor([0.8939], grad_fn=<AddBackward0>)
# new R :  5.106273651123047 f(R) :  tensor([0.8910], grad_fn=<AddBackward0>)
# new R :  5.082725524902344 f(R) :  tensor([0.8881], grad_fn=<AddBackward0>)
# new R :  5.0594987869262695 f(R) :  tensor([0.8854], grad_fn=<AddBackward0>)
# new R :  5.036591529846191 f(R) :  tensor([0.8827], grad_fn=<AddBackward0>)
# new R :  5.014001369476318 f(R) :  tensor([0.8801], grad_fn=<AddBackward0>)
# new R :  4.991725444793701 f(R) :  tensor([0.8776], grad_fn=<AddBackward0>)
# new R :  4.969761848449707 f(R) :  tensor([0.8751], grad_fn=<AddBackward0>)
# new R :  4.948107719421387 f(R) :  tensor([0.8727], grad_fn=<AddBackward0>)
# new R :  4.926760196685791 f(R) :  tensor([0.8704], grad_fn=<AddBackward0>)
# new R :  4.905717372894287 f(R) :  tensor([0.8681], grad_fn=<AddBackward0>)
# new R :  4.884976387023926 f(R) :  tensor([0.8659], grad_fn=<AddBackward0>)
# new R :  4.864534854888916 f(R) :  tensor([0.8638], grad_fn=<AddBackward0>)
# new R :  4.844390392303467 f(R) :  tensor([0.8617], grad_fn=<AddBackward0>)
# new R :  4.824540138244629 f(R) :  tensor([0.8597], grad_fn=<AddBackward0>)
# new R :  4.804981708526611 f(R) :  tensor([0.8577], grad_fn=<AddBackward0>)
# new R :  4.785712242126465 f(R) :  tensor([0.8558], grad_fn=<AddBackward0>)
# new R :  4.766729354858398 f(R) :  tensor([0.8540], grad_fn=<AddBackward0>)
# new R :  4.748030185699463 f(R) :  tensor([0.8522], grad_fn=<AddBackward0>)
# new R :  4.729612350463867 f(R) :  tensor([0.8505], grad_fn=<AddBackward0>)
# new R :  4.71147346496582 f(R) :  tensor([0.8488], grad_fn=<AddBackward0>)
# new R :  4.693610668182373 f(R) :  tensor([0.8471], grad_fn=<AddBackward0>)
# new R :  4.676021099090576 f(R) :  tensor([0.8456], grad_fn=<AddBackward0>)
# new R :  4.658702373504639 f(R) :  tensor([0.8440], grad_fn=<AddBackward0>)
# new R :  4.6416521072387695 f(R) :  tensor([0.8425], grad_fn=<AddBackward0>)
# new R :  4.6248674392700195 f(R) :  tensor([0.8411], grad_fn=<AddBackward0>)
# new R :  4.6083455085754395 f(R) :  tensor([0.8397], grad_fn=<AddBackward0>)
# new R :  4.59208345413208 f(R) :  tensor([0.8383], grad_fn=<AddBackward0>)
# new R :  4.57607889175415 f(R) :  tensor([0.8370], grad_fn=<AddBackward0>)
# new R :  4.560329437255859 f(R) :  tensor([0.8358], grad_fn=<AddBackward0>)
# new R :  4.5448317527771 f(R) :  tensor([0.8345], grad_fn=<AddBackward0>)
# new R :  4.529583930969238 f(R) :  tensor([0.8333], grad_fn=<AddBackward0>)
# new R :  4.514582633972168 f(R) :  tensor([0.8322], grad_fn=<AddBackward0>)
# new R :  4.499825477600098 f(R) :  tensor([0.8311], grad_fn=<AddBackward0>)
# new R :  4.485309600830078 f(R) :  tensor([0.8300], grad_fn=<AddBackward0>)
# new R :  4.47103214263916 f(R) :  tensor([0.8289], grad_fn=<AddBackward0>)
# new R :  4.456990718841553 f(R) :  tensor([0.8279], grad_fn=<AddBackward0>)
# new R :  4.443182468414307 f(R) :  tensor([0.8270], grad_fn=<AddBackward0>)
# new R :  4.429605007171631 f(R) :  tensor([0.8260], grad_fn=<AddBackward0>)
# new R :  4.416254997253418 f(R) :  tensor([0.8251], grad_fn=<AddBackward0>)
# new R :  4.403130054473877 f(R) :  tensor([0.8242], grad_fn=<AddBackward0>)
# new R :  4.390227794647217 f(R) :  tensor([0.8234], grad_fn=<AddBackward0>)
# new R :  4.377545356750488 f(R) :  tensor([0.8225], grad_fn=<AddBackward0>)
# new R :  4.365079879760742 f(R) :  tensor([0.8217], grad_fn=<AddBackward0>)
# new R :  4.352828502655029 f(R) :  tensor([0.8210], grad_fn=<AddBackward0>)
# new R :  4.340788841247559 f(R) :  tensor([0.8202], grad_fn=<AddBackward0>)
# new R :  4.328958034515381 f(R) :  tensor([0.8195], grad_fn=<AddBackward0>)
# new R :  4.317333698272705 f(R) :  tensor([0.8188], grad_fn=<AddBackward0>)
# new R :  4.305912971496582 f(R) :  tensor([0.8181], grad_fn=<AddBackward0>)
# new R :  4.2946929931640625 f(R) :  tensor([0.8175], grad_fn=<AddBackward0>)
# new R :  4.2836713790893555 f(R) :  tensor([0.8169], grad_fn=<AddBackward0>)
# new R :  4.27284574508667 f(R) :  tensor([0.8163], grad_fn=<AddBackward0>)
# new R :  4.262212753295898 f(R) :  tensor([0.8157], grad_fn=<AddBackward0>)
# new R :  4.251770496368408 f(R) :  tensor([0.8151], grad_fn=<AddBackward0>)
# new R :  4.24151611328125 f(R) :  tensor([0.8146], grad_fn=<AddBackward0>)
# new R :  4.231446743011475 f(R) :  tensor([0.8141], grad_fn=<AddBackward0>)
# new R :  4.221560001373291 f(R) :  tensor([0.8136], grad_fn=<AddBackward0>)
# new R :  4.211853504180908 f(R) :  tensor([0.8131], grad_fn=<AddBackward0>)
# new R :  4.202324390411377 f(R) :  tensor([0.8126], grad_fn=<AddBackward0>)
# new R :  4.192970275878906 f(R) :  tensor([0.8122], grad_fn=<AddBackward0>)
# new R :  4.183788299560547 f(R) :  tensor([0.8117], grad_fn=<AddBackward0>)
# new R :  4.174776554107666 f(R) :  tensor([0.8113], grad_fn=<AddBackward0>)
# new R :  4.1659321784973145 f(R) :  tensor([0.8109], grad_fn=<AddBackward0>)
# new R :  4.157252788543701 f(R) :  tensor([0.8105], grad_fn=<AddBackward0>)
# new R :  4.148735523223877 f(R) :  tensor([0.8101], grad_fn=<AddBackward0>)
# new R :  4.140378475189209 f(R) :  tensor([0.8098], grad_fn=<AddBackward0>)
# new R :  4.132178783416748 f(R) :  tensor([0.8094], grad_fn=<AddBackward0>)
# new R :  4.124134540557861 f(R) :  tensor([0.8091], grad_fn=<AddBackward0>)
# new R :  4.1162428855896 f(R) :  tensor([0.8088], grad_fn=<AddBackward0>)
# new R :  4.108501434326172 f(R) :  tensor([0.8085], grad_fn=<AddBackward0>)
# new R :  4.100908279418945 f(R) :  tensor([0.8082], grad_fn=<AddBackward0>)
# new R :  4.093460559844971 f(R) :  tensor([0.8079], grad_fn=<AddBackward0>)
# new R :  4.086156368255615 f(R) :  tensor([0.8076], grad_fn=<AddBackward0>)
# new R :  4.078993320465088 f(R) :  tensor([0.8074], grad_fn=<AddBackward0>)
# new R :  4.071969032287598 f(R) :  tensor([0.8071], grad_fn=<AddBackward0>)
# new R :  4.0650811195373535 f(R) :  tensor([0.8069], grad_fn=<AddBackward0>)
# new R :  4.058327674865723 f(R) :  tensor([0.8066], grad_fn=<AddBackward0>)
# new R :  4.051705837249756 f(R) :  tensor([0.8064], grad_fn=<AddBackward0>)
# new R :  4.0452141761779785 f(R) :  tensor([0.8062], grad_fn=<AddBackward0>)
# new R :  4.0388503074646 f(R) :  tensor([0.8060], grad_fn=<AddBackward0>)
# new R :  4.032611846923828 f(R) :  tensor([0.8058], grad_fn=<AddBackward0>)
# new R :  4.026496887207031 f(R) :  tensor([0.8056], grad_fn=<AddBackward0>)
# new R :  4.020503044128418 f(R) :  tensor([0.8054], grad_fn=<AddBackward0>)
# new R :  4.0146284103393555 f(R) :  tensor([0.8052], grad_fn=<AddBackward0>)
# new R :  4.008871078491211 f(R) :  tensor([0.8050], grad_fn=<AddBackward0>)
# new R :  4.003229141235352 f(R) :  tensor([0.8049], grad_fn=<AddBackward0>)
# new R :  3.9977002143859863 f(R) :  tensor([0.8047], grad_fn=<AddBackward0>)
# new R :  3.9922826290130615 f(R) :  tensor([0.8046], grad_fn=<AddBackward0>)
# new R :  3.9869742393493652 f(R) :  tensor([0.8044], grad_fn=<AddBackward0>)
# new R :  3.9817731380462646 f(R) :  tensor([0.8043], grad_fn=<AddBackward0>)
# new R :  3.976677417755127 f(R) :  tensor([0.8042], grad_fn=<AddBackward0>)
# new R :  3.9716851711273193 f(R) :  tensor([0.8040], grad_fn=<AddBackward0>)
# new R :  3.966794729232788 f(R) :  tensor([0.8039], grad_fn=<AddBackward0>)
# new R :  3.9620039463043213 f(R) :  tensor([0.8038], grad_fn=<AddBackward0>)
# new R :  3.9573111534118652 f(R) :  tensor([0.8037], grad_fn=<AddBackward0>)
# new R :  3.952714681625366 f(R) :  tensor([0.8036], grad_fn=<AddBackward0>)
# new R :  3.9482126235961914 f(R) :  tensor([0.8035], grad_fn=<AddBackward0>)
# new R :  3.943803310394287 f(R) :  tensor([0.8034], grad_fn=<AddBackward0>)
# new R :  3.9394848346710205 f(R) :  tensor([0.8033], grad_fn=<AddBackward0>)
# new R :  3.935255765914917 f(R) :  tensor([0.8032], grad_fn=<AddBackward0>)
# new R :  3.9311141967773438 f(R) :  tensor([0.8031], grad_fn=<AddBackward0>)
# new R :  3.927058696746826 f(R) :  tensor([0.8030], grad_fn=<AddBackward0>)
# new R :  3.9230875968933105 f(R) :  tensor([0.8029], grad_fn=<AddBackward0>)
# new R :  3.919199228286743 f(R) :  tensor([0.8028], grad_fn=<AddBackward0>)
# new R :  3.9153921604156494 f(R) :  tensor([0.8028], grad_fn=<AddBackward0>)
# new R :  3.9116647243499756 f(R) :  tensor([0.8027], grad_fn=<AddBackward0>)
# new R :  3.908015489578247 f(R) :  tensor([0.8026], grad_fn=<AddBackward0>)
# new R :  3.90444278717041 f(R) :  tensor([0.8026], grad_fn=<AddBackward0>)
# new R :  3.9009451866149902 f(R) :  tensor([0.8025], grad_fn=<AddBackward0>)
# new R :  3.897521495819092 f(R) :  tensor([0.8024], grad_fn=<AddBackward0>)
# new R :  3.894170045852661 f(R) :  tensor([0.8024], grad_fn=<AddBackward0>)
# new R :  3.8908894062042236 f(R) :  tensor([0.8023], grad_fn=<AddBackward0>)
# new R :  3.8876781463623047 f(R) :  tensor([0.8023], grad_fn=<AddBackward0>)
# new R :  3.884535074234009 f(R) :  tensor([0.8022], grad_fn=<AddBackward0>)
# new R :  3.8814587593078613 f(R) :  tensor([0.8022], grad_fn=<AddBackward0>)
# new R :  3.878448009490967 f(R) :  tensor([0.8021], grad_fn=<AddBackward0>)
# new R :  3.8755013942718506 f(R) :  tensor([0.8021], grad_fn=<AddBackward0>)
# new R :  3.872617721557617 f(R) :  tensor([0.8020], grad_fn=<AddBackward0>)
# new R :  3.869795560836792 f(R) :  tensor([0.8020], grad_fn=<AddBackward0>)
# new R :  3.8670339584350586 f(R) :  tensor([0.8020], grad_fn=<AddBackward0>)
# new R :  3.8643314838409424 f(R) :  tensor([0.8019], grad_fn=<AddBackward0>)
# new R :  3.861686944961548 f(R) :  tensor([0.8019], grad_fn=<AddBackward0>)
# new R :  3.8590993881225586 f(R) :  tensor([0.8018], grad_fn=<AddBackward0>)
# new R :  3.8565673828125 f(R) :  tensor([0.8018], grad_fn=<AddBackward0>)
# new R :  3.8540899753570557 f(R) :  tensor([0.8018], grad_fn=<AddBackward0>)
# new R :  3.85166597366333 f(R) :  tensor([0.8017], grad_fn=<AddBackward0>)
# new R :  3.849294424057007 f(R) :  tensor([0.8017], grad_fn=<AddBackward0>)
# new R :  3.8469741344451904 f(R) :  tensor([0.8017], grad_fn=<AddBackward0>)
# new R :  3.8447041511535645 f(R) :  tensor([0.8017], grad_fn=<AddBackward0>)
# new R :  3.8424832820892334 f(R) :  tensor([0.8016], grad_fn=<AddBackward0>)
# new R :  3.840310573577881 f(R) :  tensor([0.8016], grad_fn=<AddBackward0>)
# new R :  3.8381850719451904 f(R) :  tensor([0.8016], grad_fn=<AddBackward0>)
# new R :  3.8361058235168457 f(R) :  tensor([0.8016], grad_fn=<AddBackward0>)
# new R :  3.8340718746185303 f(R) :  tensor([0.8015], grad_fn=<AddBackward0>)
# new R :  3.8320822715759277 f(R) :  tensor([0.8015], grad_fn=<AddBackward0>)
# new R :  3.8301360607147217 f(R) :  tensor([0.8015], grad_fn=<AddBackward0>)
# new R :  3.828232526779175 f(R) :  tensor([0.8015], grad_fn=<AddBackward0>)
# new R :  3.8263704776763916 f(R) :  tensor([0.8015], grad_fn=<AddBackward0>)
# new R :  3.8245491981506348 f(R) :  tensor([0.8015], grad_fn=<AddBackward0>)
# new R :  3.822767972946167 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.8210256099700928 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.819321632385254 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.817655086517334 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.8160250186920166 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.8144309520721436 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.8128719329833984 f(R) :  tensor([0.8014], grad_fn=<AddBackward0>)
# new R :  3.811347246170044 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.8098561763763428 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.8083980083465576 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.806972026824951 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.8055777549743652 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.8042142391204834 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.8028810024261475 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.801577091217041 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.800302267074585 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.799055576324463 f(R) :  tensor([0.8013], grad_fn=<AddBackward0>)
# new R :  3.7978365421295166 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.796644687652588 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7954792976379395 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.794339895248413 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7932257652282715 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7921364307403564 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7910714149475098 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7900302410125732 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7890121936798096 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7880167961120605 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.787043809890747 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.786092519760132 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7851624488830566 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7842531204223633 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7833640575408936 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7824950218200684 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7816455364227295 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7808148860931396 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7800028324127197 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.7792091369628906 f(R) :  tensor([0.8012], grad_fn=<AddBackward0>)
# new R :  3.778433084487915 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.777674674987793 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.776933193206787 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7762084007263184 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7754998207092285 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7748072147369385 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.77413010597229 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.773468255996704 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7728214263916016 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.772189140319824 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.771570920944214 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7709667682647705 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.770376205444336 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.769798994064331 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7692346572875977 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7686831951141357 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.768144130706787 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7676172256469727 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7671022415161133 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.766598701477051 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.766106605529785 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7656257152557373 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.765155553817749 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7646961212158203 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.764247179031372 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.763808250427246 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7633793354034424 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7629599571228027 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.762550115585327 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7621495723724365 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7617580890655518 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7613754272460938 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7610015869140625 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7606360912323 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7602789402008057 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.759929895401001 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7595887184143066 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7592554092407227 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.758929491043091 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.758610963821411 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7582998275756836 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.75799560546875 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7576982975006104 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7574076652526855 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7571237087249756 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7568461894989014 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.756574869155884 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.756309747695923 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7560508251190186 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7557976245880127 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7555501461029053 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7553083896636963 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7550721168518066 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7548410892486572 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.754615545272827 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.754395008087158 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7541794776916504 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7539689540863037 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.753763198852539 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7535619735717773 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7533652782440186 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7531731128692627 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7529854774475098 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7528021335601807 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7526228427886963 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7524476051330566 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7522764205932617 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7521090507507324 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7519454956054688 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7517857551574707 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.751629590988159 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.751477003097534 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7513279914855957 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7511823177337646 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.751039981842041 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7509007453918457 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.750764846801758 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7506320476531982 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.750502109527588 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.750375270843506 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.750251293182373 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7501301765441895 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.750011682510376 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7498958110809326 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7497828006744385 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7496721744537354 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7495641708374023 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7494585514068604 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7493553161621094 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7492544651031494 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7491559982299805 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7490596771240234 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7489657402038574 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.748873710632324 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.748783826828003 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7486960887908936 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.748610258102417 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7485263347625732 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7484443187713623 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.748364210128784 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.748286008834839 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7482094764709473 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7481348514556885 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7480618953704834 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.747990608215332 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7479209899902344 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7478528022766113 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.747786283493042 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7477211952209473 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7476577758789062 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.74759578704834 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.747535228729248 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7474758625030518 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.74741792678833 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.747361421585083 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7473061084747314 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7472519874572754 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.747199058532715 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.747147560119629 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7470970153808594 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7470476627349854 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.746999502182007 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.746952533721924 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7469065189361572 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.746861457824707 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)
# new R :  3.7468175888061523 f(R) :  tensor([0.8011], grad_fn=<AddBackward0>)

# %%
import matplotlib.pyplot as plt
plt.plot(R,value,"+",label= "optimization steps")
#plt.plot(r,y,label= "theoretical curve")
plt.axvline(R_opt,linestyle="--",label=f"optimal radius {np.round(R_opt,2)}")
plt.xlabel("Radius (cm)" , fontsize =17)
plt.ylabel("Surface Volume ratio (cm^-1)", fontsize =17)
plt.axvline(20,linestyle="--",label="init",color="k")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-aee86acaa985> in <cell line: 0>()
#       2 plt.plot(R,value,"+",label= "optimization steps")
#       3 #plt.plot(r,y,label= "theoretical curve")
# ----> 4 plt.axvline(R_opt,linestyle="--",label=f"optimal radius {np.round(R_opt,2)}")
#       5 plt.xlabel("Radius (cm)" , fontsize =17)
#       6 plt.ylabel("Surface Volume ratio (cm^-1)", fontsize =17)
#
# NameError: name 'R_opt' is not defined
